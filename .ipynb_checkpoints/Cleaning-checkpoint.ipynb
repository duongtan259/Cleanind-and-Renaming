# %%
import pandas as pd
import numpy as np
pd.options.mode.chained_assignment = None

# %%
# read text file into pandas DataFrame
df = pd.read_table("all_table_definitions.txt", delimiter="|", encoding= 'unicode_escape')

# %%
df.rename(columns=lambda x: x.strip(), inplace=True)

# %%
new = df[df['Field Name'].str.contains('Table     :')]['Field Name'].str.split(' ', expand=True)[6]
index= new.index.values

# %%
df1= df.copy()
df1['Table Name'] = np.NaN
df1.loc[index, ['Table Name']] = new.values
df1.head()
# Out:
#                                           Field Name  \
# 0
# 1  ---------------+------------------------------...
# 2                                      1  indt
# 3                                      2  dsca
# 4                                      3  wfrc
#
#                                          Description             Domain  \
# 0                                                ...
# 1                                                NaN                NaN
# 2                                                ...   tcdate
# 3                                                ...   tcmcs.str50m
# 4                                                ...   asint.wfld
#
#     Datatype     Physic.    Mand.     Acti      Refer.   Reference Table Name
# 0                length                              Table    Mode        NaN
# 1                    NaN      NaN      NaN                     NaN        NaN
# 2   UTC Date/T        4    No       Yes               Not applicab        NaN
# 3   Multibyte       200    No       Yes               Not applicab        NaN
# 4                     0    No       Yes               Not applicab        NaN

# %%
df1['Table Name'].fillna(method='ffill', inplace=True)
df1
# Out:
#                                                Field Name  \
# 0
# 1       ---------------+------------------------------...
# 2                                           1  indt
# 3                                           2  dsca
# 4                                           3  wfrc
# ...                                                   ...
# 487670                                              4
# 487671
# 487672                                              5
# 487673
# 487674  ----------------------------------------------...
#
#                                               Description  \
# 0                                                     ...
# 1                                                     NaN
# 2                                                     ...
# 3                                                     ...
# 4                                                     ...
# ...                                                   ...
# 487670   Item, Serial, Warehouse, Lot, Location, Inven...
# 487671                                          ( Part...
# 487672   Warehouse, Item, Project                     ...
# 487673                                          ( Part...
# 487674                                                NaN
#
#                                                    Domain  \
# 0
# 1                                                     NaN
# 2                                        tcdate
# 3                                        tcmcs.str50m
# 4                                        asint.wfld
# ...                                                   ...
# 487670   item     serl     cwar     clot     loca     ...
# 487671   cstl     ccco     owns     ownr     bfbp     ...
# 487672   cwar     item     cprj     cspa     cact     ...
# 487673   serl     spcn     owns     ownr     bfbp     ...
# 487674                                                NaN
#
#          Datatype     Physic.    Mand.     Acti      Refer.   Reference  \
# 0                     length                              Table    Mode
# 1                         NaN      NaN      NaN                     NaN
# 2        UTC Date/T        4    No       Yes               Not applicab
# 3        Multibyte       200    No       Yes               Not applicab
# 4                          0    No       Yes               Not applicab
# ...                       ...      ...      ...                     ...
# 487670                 No          Yes      NaN                     NaN
# 487671                             NaN      NaN                     NaN
# 487672                 No          Yes      NaN                     NaN
# 487673                             NaN      NaN                     NaN
# 487674                    NaN      NaN      NaN                     NaN
#
#        Table Name
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 487670   whwmd694
# 487671   whwmd694
# 487672   whwmd694
# 487673   whwmd694
# 487674   whwmd694
#
# [487675 rows x 8 columns]

# %%
new1 = df1[df1['Field Name'].str.contains('Delete Reference Message')]['Field Name'].str.split(' ', expand=True)[8]
index1= new.index.values

# %%
df2= df1.copy()
df2['VCR'] = np.NaN
df2.loc[index1, ['VCR']] = new1.values
df2.head()
# Out:
#                                           Field Name  \
# 0
# 1  ---------------+------------------------------...
# 2                                      1  indt
# 3                                      2  dsca
# 4                                      3  wfrc
#
#                                          Description             Domain  \
# 0                                                ...
# 1                                                NaN                NaN
# 2                                                ...   tcdate
# 3                                                ...   tcmcs.str50m
# 4                                                ...   asint.wfld
#
#     Datatype     Physic.    Mand.     Acti      Refer.   Reference Table Name  \
# 0                length                              Table    Mode        NaN
# 1                    NaN      NaN      NaN                     NaN        NaN
# 2   UTC Date/T        4    No       Yes               Not applicab        NaN
# 3   Multibyte       200    No       Yes               Not applicab        NaN
# 4                     0    No       Yes               Not applicab        NaN
#
#    VCR
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN

# %%
df2['VCR'].fillna(method='ffill', inplace=True)
df2
# Out:
#                                                Field Name  \
# 0
# 1       ---------------+------------------------------...
# 2                                           1  indt
# 3                                           2  dsca
# 4                                           3  wfrc
# ...                                                   ...
# 487670                                              4
# 487671
# 487672                                              5
# 487673
# 487674  ----------------------------------------------...
#
#                                               Description  \
# 0                                                     ...
# 1                                                     NaN
# 2                                                     ...
# 3                                                     ...
# 4                                                     ...
# ...                                                   ...
# 487670   Item, Serial, Warehouse, Lot, Location, Inven...
# 487671                                          ( Part...
# 487672   Warehouse, Item, Project                     ...
# 487673                                          ( Part...
# 487674                                                NaN
#
#                                                    Domain  \
# 0
# 1                                                     NaN
# 2                                        tcdate
# 3                                        tcmcs.str50m
# 4                                        asint.wfld
# ...                                                   ...
# 487670   item     serl     cwar     clot     loca     ...
# 487671   cstl     ccco     owns     ownr     bfbp     ...
# 487672   cwar     item     cprj     cspa     cact     ...
# 487673   serl     spcn     owns     ownr     bfbp     ...
# 487674                                                NaN
#
#          Datatype     Physic.    Mand.     Acti      Refer.   Reference  \
# 0                     length                              Table    Mode
# 1                         NaN      NaN      NaN                     NaN
# 2        UTC Date/T        4    No       Yes               Not applicab
# 3        Multibyte       200    No       Yes               Not applicab
# 4                          0    No       Yes               Not applicab
# ...                       ...      ...      ...                     ...
# 487670                 No          Yes      NaN                     NaN
# 487671                             NaN      NaN                     NaN
# 487672                 No          Yes      NaN                     NaN
# 487673                             NaN      NaN                     NaN
# 487674                    NaN      NaN      NaN                     NaN
#
#        Table Name    VCR
# 0             NaN    NaN
# 1             NaN    NaN
# 2             NaN    NaN
# 3             NaN    NaN
# 4             NaN    NaN
# ...           ...    ...
# 487670   whwmd694  107U0
# 487671   whwmd694  107U0
# 487672   whwmd694  107U0
# 487673   whwmd694  107U0
# 487674   whwmd694  107U0
#
# [487675 rows x 9 columns]

# %%
df3 = df2[df2['VCR'] == '107U0']
df3
# Out:
#                                                Field Name  \
# 22      Table     : asint000                          ...
# 23      VRC       : 107U0 a000  (Update)              ...
# 24                                                    ...
# 25      ----------------------------------------------...
# 26                                        Field Name
# ...                                                   ...
# 487670                                              4
# 487671
# 487672                                              5
# 487673
# 487674  ----------------------------------------------...
#
#                                               Description  \
# 22                                                    NaN
# 23                                                    NaN
# 24                                                    NaN
# 25                                                    NaN
# 26       Description                                  ...
# ...                                                   ...
# 487670   Item, Serial, Warehouse, Lot, Location, Inven...
# 487671                                          ( Part...
# 487672   Warehouse, Item, Project                     ...
# 487673                                          ( Part...
# 487674                                                NaN
#
#                                                    Domain  \
# 22                                                    NaN
# 23                                                    NaN
# 24                                                    NaN
# 25                                                    NaN
# 26                                       Domain
# ...                                                   ...
# 487670   item     serl     cwar     clot     loca     ...
# 487671   cstl     ccco     owns     ownr     bfbp     ...
# 487672   cwar     item     cprj     cspa     cact     ...
# 487673   serl     spcn     owns     ownr     bfbp     ...
# 487674                                                NaN
#
#          Datatype     Physic.    Mand.     Acti   Refer.   Reference  \
# 22                        NaN      NaN      NaN                  NaN
# 23                        NaN      NaN      NaN                  NaN
# 24                        NaN      NaN      NaN                  NaN
# 25                        NaN      NaN      NaN                  NaN
# 26       Datatype     Physic.   Mand.    Acti     Refer.   Reference
# ...                       ...      ...      ...                  ...
# 487670                 No          Yes      NaN                  NaN
# 487671                             NaN      NaN                  NaN
# 487672                 No          Yes      NaN                  NaN
# 487673                             NaN      NaN                  NaN
# 487674                    NaN      NaN      NaN                  NaN
#
#        Table Name    VCR
# 22       asint000  107U0
# 23       asint000  107U0
# 24       asint000  107U0
# 25       asint000  107U0
# 26       asint000  107U0
# ...           ...    ...
# 487670   whwmd694  107U0
# 487671   whwmd694  107U0
# 487672   whwmd694  107U0
# 487673   whwmd694  107U0
# 487674   whwmd694  107U0
#
# [192376 rows x 9 columns]

# %%
table_name = ['tccom001', 'tcmcs002', 'tcmcs010', 'tcmcs015', 'tcmcs023', 'tiedm010', 'tiedm100', 'tiedm110']

# %%
appended_data = []
table_data = []
for name in table_name:
    try:
        newdf = df3[df3['Table Name'].str.contains(name)].dropna(subset=['Field Name','Description'])
        list_numbers = str([1, 2, 3, 4, 5, 6, 7, 8, 9])
        newdf1 = newdf[newdf['Field Name'].str.strip().astype(str).str.startswith(tuple(list_numbers))]
        newdf1['Field Name'] = newdf1['Field Name'].str.split(' ', expand=True, n=3)[3].str.strip()
        nan_value = float("NaN")
        newdf1.replace("", nan_value, inplace=True)
        newdf1.dropna(subset = ["Field Name"], inplace=True)
        newdf1['Description'] = newdf1['Description'].str.split('(', expand=True, n=1)[0].str.strip()
        appended_data.append(newdf1)
        table_data.append(name)
    except ValueError: 
        print("A ValueError occurred")
    except:
        print(name, "does not have any information" )
appended_data = pd.concat(appended_data)
print(table_data, "does have information")
# Out:
# tcmcs015 does not have any information
# ['tccom001', 'tcmcs002', 'tcmcs010', 'tcmcs023', 'tiedm010', 'tiedm100', 'tiedm110'] does have information

# %%
appended_data.to_excel('test.xlsx')
